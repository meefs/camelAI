# %% [markdown]
# # Sales Snapshot
# Notebook scaffold output rendered by the static worker.

# %% [markdown]
# ## Monthly totals
# This sample includes a markdown section, text output, and a dataframe-like HTML table output.

# %%
print('Loaded 12 rows from notebook input.')
print('Rendering with copied Chiridion notebook renderer.')
# Out:
# Loaded 12 rows from notebook input.
# Rendering with copied Chiridion notebook renderer.

# %%
import pandas as pd
df = pd.DataFrame({'month': ['Jan', 'Feb', 'Mar'], 'revenue': [12000, 15400, 16750]})
df
# Out:
#   month  revenue\n0   Jan    12000\n1   Feb    15400\n2   Mar    16750
